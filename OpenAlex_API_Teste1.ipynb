# %% [markdown]
# <a href="https://colab.research.google.com/github/andreinaabrantes/OpenAlex_API/blob/main/OpenAlex_API_Teste1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
MAILTO = "1andre.abrantes@gmail.com"

SEARCH_TERMS = [
    "Floresta Nacional de Pau-Rosa",
    "FN de Pau-Rosa",
    "FLONA de Pau-Rosa",
    "Pau-Rosa National Forest",
    "National Forest of Pau-Rosa",
    "Bosque Nacional de Pau-Rosa",
]

search_query = " OR ".join(f'"{term}"' for term in SEARCH_TERMS)

BASE = "https://api.openalex.org/works"

# %%
print(search_query)

# %%
params = {
    "search": search_query,
    "per-page": 10,
    "select": "id,title,publication_year",
    "mailto": MAILTO,
}

# %%
r = requests.get(BASE, params=params, timeout=60)
r.raise_for_status()
data = r.json()

print("Total (meta.count):", data.get("meta", {}).get("count"))
print("Itens nesta página:", len(data.get("results", [])))
for w in data.get("results", []):
    print("-", w.get("publication_year"), "|", w.get("title"), "|",
          (w.get("host_venue") or {}).get("display_name"), "|", w.get("doi"))
